# %% [markdown]
# ## Initialization

# %%
# %%shell
# # For PySpark
# # ref: https://www.alura.com.br/artigos/iniciando-projeto-spark-no-colab
# apt-get install openjdk-8-jdk-headless -qq > /dev/null
# wget -q https://archive.apache.org/dist/spark/spark-3.1.2/spark-3.1.2-bin-hadoop2.7.tgz
# tar xf spark-3.1.2-bin-hadoop2.7.tgz
# pip install -q findspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting colab-xterm
#   Downloading colab_xterm-0.1.2-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 5.0 MB/s
# Requirement already satisfied: tornado>5.1 in /usr/local/lib/python3.7/dist-packages (from colab-xterm) (6.0.4)
# Requirement already satisfied: ptyprocess~=0.7.0 in /usr/local/lib/python3.7/dist-packages (from colab-xterm) (0.7.0)
# Installing collected packages: colab-xterm
# Successfully installed colab-xterm-0.1.2

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.2-bin-hadoop2.7"
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .master('local[*]') \
    .appName('Iniciando com Spark') \
    .config('spark.ui.port', '4050') \
    .getOrCreate()

# %%
filename = "dataset_bruto.json"

# %% [markdown]
# ## Terminal

# %%
# %load_ext colabxterm
# %xterm

# %% [markdown]
# ## Preprocessing

# %%
from pyspark.sql import functions as sf
from pyspark.sql import udf
from pyspark.sql.types import *

# %%
sdf_raw = spark.read.json(proj_path+"data/"+filename, multiLine=True)
sdf_anuncio = sdf_raw.select("anuncio").rdd.map(lambda x: x[0]).toDF()

# %% [markdown]
# ### Unpacking features

# %%
# Unpacking values 1
lt_cols = ["quartos", "suites", "banheiros", "vaga", "area_total", "area_util"]
sdf_anuncio = (
    sdf_anuncio.select(
        *[sf.col(i)[0].alias(i) for i in lt_cols] 
        +[i for i in sdf_anuncio.columns if not i in lt_cols]
    )
)

# %%
# Unpacking values 2
sdf_valores = sdf_anuncio.select("valores").rdd.map(lambda x: x[0][0]).toDF()
sdf_endereco = sdf_anuncio.select("endereco").rdd.map(lambda x: x[0]).toDF()

def enumerate_rows(sdf, name="index"):
  return sdf.withColumn(name, sf.monotonically_increasing_id())

sdf_anuncio = (
    enumerate_rows(sdf_anuncio)
    .join(
      enumerate_rows(sdf_valores), on=["index"], how="left"
    )
    .join(
      enumerate_rows(sdf_endereco), on=["index"], how="left"
    )
    .drop("index")
)

# %%
sdf_anuncio.show(5)
# Out:
# +-------+------+---------+----+----------+---------+-----+--------------------+--------------------+--------------------+------------+------------+-----------+--------------------+----------+----+-----+------+--------------------+--------+--------------+--------------+----------+----------+----+--------------------+------------+
# |quartos|suites|banheiros|vaga|area_total|area_util|andar|     caracteristicas|            endereco|                  id|tipo_anuncio|tipo_unidade|   tipo_uso|             valores|condominio|iptu| tipo| valor|              bairro|     cep|        cidade|        estado|  latitude| longitude|pais|                 rua|        zona|
# +-------+------+---------+----+----------+---------+-----+--------------------+--------------------+--------------------+------------+------------+-----------+--------------------+----------+----+-----+------+--------------------+--------+--------------+--------------+----------+----------+----+--------------------+------------+
# |      0|  null|        0|   1|        14|       14|    0|[Elevador, Portar...|{Centro, 20071000...|044617ee-2707-412...|       Usado|      Outros|  Comercial|[{330, 1070, Vend...|       330|1070|Venda| 12000|              Centro|20071000|Rio de Janeiro|Rio de Janeiro|-22.901964|-43.179998|  BR|Avenida President...|Zona Central|
# |      2|  null|        1|   1|        60|       60|    0|[Condomínio fechado]|{Pedra de Guarati...|dc99d9e1-4c63-41f...|       Usado| Apartamento|Residencial|[{0, 0, Venda, 15...|         0|   0|Venda| 15000|  Pedra de Guaratiba|23025018|Rio de Janeiro|Rio de Janeiro|-22.991393|-43.628042|  BR|Rua Cento e Trint...|  Zona Oeste|
# |      0|  null|        0|null|       120|      120|    0|[Portão eletrônic...|{Campo Grande, 23...|2565c87e-63f7-409...|       Usado|      Outros|Residencial|[{100, null, Vend...|       100|null|Venda| 80000|        Campo Grande|23095071|Rio de Janeiro|Rio de Janeiro|-22.885028|-43.561668|  BR|Estrada Guandu do...|  Zona Oeste|
# |      0|     0|        1|   1|        23|       23|    3|                  []|{Recreio dos Band...|8b23d7ff-54e3-476...|       Usado|      Outros|  Comercial|[{619, 2000, Vend...|       619|2000|Venda| 95000|Recreio dos Bande...|22790682|Rio de Janeiro|Rio de Janeiro|-23.005235|-43.480353|  BR|Avenida Miguel An...|  Zona Oeste|
# |      2|     0|        1|   1|     16546|       50|    0|[Churrasqueira, P...|{Bangu, 21830008,...|5c1ccfd0-5a9a-4d1...|       Usado| Apartamento|Residencial|[{360, 0, Venda, ...|       360|   0|Venda|125000|               Bangu|21830008|Rio de Janeiro|Rio de Janeiro|-22.882249|-43.482333|  BR|Avenida de Santa ...|  Zona Oeste|
# +-------+------+---------+----+----------+---------+-----+--------------------+--------------------+--------------------+------------+------------+-----------+--------------------+----------+----+-----+------+--------------------+--------+--------------+--------------+----------+----------+----+--------------------+------------+
# only showing top 5 rows

# %% [markdown]
# ### Filtering

# %%
lt_filters = [
    'tipo_uso == "Residencial"', 
    'tipo_unidade == "Apartamento"', 
    'tipo_anuncio == "Usado"', 
    'tipo == "Venda"'
    ]
    
lt_cols_drop = ["valores", "endereco", "cep", "cidade", "estado", "latitude", "longitude", "país", "rua"]

# %%
sdf_anuncio_filt = sdf_anuncio.where(" and ".join(lt_filters))
sdf_anuncio_filt = sdf_anuncio_filt.drop(*lt_cols_drop)

# %%
sdf_anuncio_filt.show(5)
# Out:
# +-------+------+---------+----+----------+---------+-----+--------------------+--------------------+------------+------------+-----------+----------+----+-----+------+------------------+----+----------+
# |quartos|suites|banheiros|vaga|area_total|area_util|andar|     caracteristicas|                  id|tipo_anuncio|tipo_unidade|   tipo_uso|condominio|iptu| tipo| valor|            bairro|pais|      zona|
# +-------+------+---------+----+----------+---------+-----+--------------------+--------------------+------------+------------+-----------+----------+----+-----+------+------------------+----+----------+
# |      2|  null|        1|   1|        60|       60|    0|[Condomínio fechado]|dc99d9e1-4c63-41f...|       Usado| Apartamento|Residencial|         0|   0|Venda| 15000|Pedra de Guaratiba|  BR|Zona Oeste|
# |      2|     0|        1|   1|     16546|       50|    0|[Churrasqueira, P...|5c1ccfd0-5a9a-4d1...|       Usado| Apartamento|Residencial|       360|   0|Venda|125000|             Bangu|  BR|Zona Oeste|
# |      2|     0|        1|   1|        47|       47|    0|                  []|325e3c76-ff8b-491...|       Usado| Apartamento|Residencial|       350|  50|Venda|139900|        Praça Seca|  BR|Zona Oeste|
# |      2|     0|        1|   0|        55|       55|    0|                  []|16a53dd9-044f-4a4...|       Usado| Apartamento|Residencial|       720|   0|Venda|135000|      Campo Grande|  BR|Zona Oeste|
# |      2|  null|        1|null|      null|       62|    0|                  []|a5f7a710-0648-477...|       Usado| Apartamento|Residencial|         0|   0|Venda|148580|        Praça Seca|  BR|Zona Oeste|
# +-------+------+---------+----+----------+---------+-----+--------------------+--------------------+------------+------------+-----------+----------+----+-----+------+------------------+----+----------+
# only showing top 5 rows

# %% [markdown]
# ## Saving file

# %%
sdf_anuncio_filt.write.parquet("dataset_tratado")
